# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

drive_folder_path = '/content/drive/MyDrive/Python/Python/'
files_drive = os.listdir(drive_folder_path)


file_path = '/content/drive/MyDrive/Python/Python/new2.txt'
with open(file_path, 'r') as file:
    tex_content = file.read()
print(tex_content)
# Out:
# dfsgdgdsfrg
#
# ddsfb ddsfb
# r
# r
# r
# r
# rn
#
# mn
# n
# n

# %%
with open(file_path, 'r') as file:
 for line in file :
  print ( line . strip () )
# Out:
# HelloWorld !

# %%
from posix import write
file_path = '/content/drive/MyDrive/Python/Python/new2.txt'

with open(file_path, 'w') as file:
 file . write ('HelloWorld !\n')

with open(file_path, 'r') as file:
    tex_content = file.read()
print(tex_content)
# Out:
# HelloWorld !

# %%
f = '/content/drive/MyDrive/Python/Python/new3.txt'

with open (f,'w') as file:
 file.write(tex_content)

 with open(file_path, 'r') as file:
    tex_content2 = file.read()
print(tex_content2)
# Out:
# HelloWorld !

# %%
f = '/content/drive/MyDrive/Python/Python/new3.txt'

with open (f,'a') as file:
 file.write(tex_content2)

 with open(f, 'r') as file:
    tex_content3 = file.read()
print(tex_content3)
# Out:
# HelloWorld !
# HelloWorld !
# HelloWorld !
# HelloWorld !
# HelloWorld !

# %%
f = '/content/drive/MyDrive/Python/Python/new3.txt'

with open (f,'a') as file:
 file.write('today.\n')

 with open(f, 'r') as file:
    tex_content3 = file.read()
print(tex_content3)
# Out:
# HelloWorld !
# HelloWorld !
# HelloWorld !
# HelloWorld !
# HelloWorld !
# HelloWorld !
# todaytodaytodaytoday
# today.
# today.
# today.
# today.
# today.

# %%
f = '/content/drive/MyDrive/Python/Python/new4.txt'

with open (f,'a') as file:
 file.write('today \n')

 with open(f, 'r') as file:
    tex_content3 = file.read()
print(tex_content3)
# Out:
# today.
# today.
# today.
# today.
# today.
# today.
# today.
# today.
# today
# today
# today
